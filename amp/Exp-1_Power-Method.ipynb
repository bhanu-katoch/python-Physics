# %%
# work for even 3X3 matrix
import numpy as np 
#a=np.array([[2,-12],[1,-5]])
#a=np.array([[2,0,0],[0,3,4],[0,4,9]])
a=np.array([[4,2],[3,1]])
x=np.array([1,1])
o=2
eps=0.001

def large(arr,n):
	max=arr[0]
	for i in range(1,n):
		if(abs(arr[i])>abs(max)):
			max=arr[i]
	return max
	
s=[0,0]
i=0

while(i<=1 or (abs(abs(s[i+1])-abs(s[i]))>=eps)):
	xx=np.matmul(a,x)
	f=large(xx,o)
	x=np.true_divide(xx,f)
	s.append(f)
	i+=1

print("eigen-vector:",x)
print("eigen-value:",f)
# Out:
# eigen-vector: [1.         0.68614021]
# eigen-value: 5.372294372294372
